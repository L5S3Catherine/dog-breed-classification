# %%
import os
import warnings
import random
from shutil import copyfile
import numpy as np
import pandas as pd
import itertools
#data visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pathlib
#deep learning libraries
import tensorflow as tf
from keras.optimizers import Adam
from keras.layers import Conv2D, Flatten, Dense, MaxPooling2D, Dropout
from keras.models import Sequential
from mpl_toolkits.axes_grid1 import ImageGrid
from keras.preprocessing.image import ImageDataGenerator
#importing ResNet50 model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions

# %%
#train and test directories
dir_train='D:/大四/Project/dog-breed-identification(1)/train'
dir_test='D:/大四/Project/dog-breed-identification(1)/test'

#labels have image name and dog breed in a csv file and sample_submission contain details of test set
df_train= pd.read_csv('D:/大四/Project/dog-breed-identification(1)/labels.csv',dtype=str)
df_test= pd.read_csv('D:/大四/Project/dog-breed-identification(1)/sample_submission.csv',dtype=str)

# %%
#images are in jpg format and to match their names in csv file we appending 'jpg' in it
def append_ext(fn):
    return fn+".jpg"

# %%
df_train["id"] = df_train["id"].apply(append_ext)
df_test["id"] = df_test["id"].apply(append_ext)

# %%
#As instructed all other breeds except suggested ones are deleted
inc_breed=['beagle','chihuahua','doberman','french_bulldog','golden_retriever','malamute','pug','saint_bernard', 'scottish_deerhound',
'tibetan_mastiff']
for i,breed in df_train.iterrows():
    if breed[1] not in inc_breed:
        df_train=df_train.drop([i])
       
len(df_train)
# Out:
# 841

# %%
print(df_train.head())
df_test.head()
# Out:
#                                       id               breed
# 4   0021f9ceb3235effd7fcde7f7538ed62.jpg    golden_retriever
# 9   0042188c895a2f14ef64a918ed9c7b64.jpg  scottish_deerhound
# 20  008b1271ed1addaccf93783b39deab45.jpg            doberman
# 25  00a366d4b4a9bbb6c8a63126697b7656.jpg    golden_retriever
# 37  0100f55e4f0fe28f2c0465d3fc4b9897.jpg    golden_retriever
#                                      id        affenpinscher  \
# 0  000621fb3cbb32d8935728e48679680e.jpg  0.00833333333333333
# 1  00102ee9d8eb90812350685311fe5890.jpg  0.00833333333333333
# 2  0012a730dfa437f5f3613fb75efcd4ce.jpg  0.00833333333333333
# 3  001510bc8570bbeee98c8d80c8a95ec1.jpg  0.00833333333333333
# 4  001a5f3114548acdefa3d4da05474c2e.jpg  0.00833333333333333
#
#           afghan_hound  african_hunting_dog             airedale  \
# 0  0.00833333333333333  0.00833333333333333  0.00833333333333333
# 1  0.00833333333333333  0.00833333333333333  0.00833333333333333
# 2  0.00833333333333333  0.00833333333333333  0.00833333333333333
# 3  0.00833333333333333  0.00833333333333333  0.00833333333333333
# 4  0.00833333333333333  0.00833333333333333  0.00833333333333333
#
#   american_staffordshire_terrier          appenzeller   australian_terrier  \
# 0            0.00833333333333333  0.00833333333333333  0.00833333333333333
# 1            0.00833333333333333  0.00833333333333333  0.00833333333333333
# 2            0.00833333333333333  0.00833333333333333  0.00833333333333333
# 3            0.00833333333333333  0.00833333333333333  0.00833333333333333
# 4            0.00833333333333333  0.00833333333333333  0.00833333333333333
#
#                basenji               basset  ...           toy_poodle  \
# 0  0.00833333333333333  0.00833333333333333  ...  0.00833333333333333
# 1  0.00833333333333333  0.00833333333333333  ...  0.00833333333333333
# 2  0.00833333333333333  0.00833333333333333  ...  0.00833333333333333
# 3  0.00833333333333333  0.00833333333333333  ...  0.00833333333333333
# 4  0.00833333333333333  0.00833333333333333  ...  0.00833333333333333
#
#            toy_terrier               vizsla         walker_hound  \
# 0  0.00833333333333333  0.00833333333333333  0.00833333333333333
# 1  0.00833333333333333  0.00833333333333333  0.00833333333333333
# 2  0.00833333333333333  0.00833333333333333  0.00833333333333333
# 3  0.00833333333333333  0.00833333333333333  0.00833333333333333
# 4  0.00833333333333333  0.00833333333333333  0.00833333333333333
#
#             weimaraner welsh_springer_spaniel west_highland_white_terrier  \
# 0  0.00833333333333333    0.00833333333333333         0.00833333333333333
# 1  0.00833333333333333    0.00833333333333333         0.00833333333333333
# 2  0.00833333333333333    0.00833333333333333         0.00833333333333333
# 3  0.00833333333333333    0.00833333333333333         0.00833333333333333
# 4  0.00833333333333333    0.00833333333333333         0.00833333333333333
#
#                whippet wire-haired_fox_terrier    yorkshire_terrier
# 0  0.00833333333333333     0.00833333333333333  0.00833333333333333
# 1  0.00833333333333333     0.00833333333333333  0.00833333333333333
# 2  0.00833333333333333     0.00833333333333333  0.00833333333333333
# 3  0.00833333333333333     0.00833333333333333  0.00833333333333333
# 4  0.00833333333333333     0.00833333333333333  0.00833333333333333
#
# [5 rows x 121 columns]

# %%
#display some images with help of matplotlib
source_path = 'D:/大四/Project/dog-breed-identification(1)/train'
sub_class = os.listdir(source_path)

fig = plt.figure(figsize=(10,5))
for i in range(len(sub_class[:8])):
    plt.subplot(2,4,i+1)
    imag = plt.imread(os.path.join(source_path,sub_class[i+7]))
    plt.imshow(imag, cmap=plt.get_cmap('gray'))
    plt.axis('off')

# %%
#Generating batches of tensor image data with real-time data augmentation.
train_datagen=ImageDataGenerator( rescale=1./255.,
                                  rotation_range = 20,
                                  brightness_range=[0.2,1.0],
                                  width_shift_range = 0.2,
                                  height_shift_range = 0.2,
                        
                                  horizontal_flip = True,
                                
                                  validation_split=0.1
                                  )

# %%
#Generating batches of tensor image data with real-time data augmentation for training set.
train_generator=train_datagen.flow_from_dataframe(
directory=dir_train,
dataframe=df_train,
x_col="id",
y_col="breed",
subset="training",
batch_size=32,
seed=42,
shuffle=True,
class_mode="categorical",
target_size=(224,224)

)
# Out:
# Found 757 validated image filenames belonging to 10 classes.

# %%
#Generating batches of tensor image data with real-time data augmentation for validation set set.
validation_generator=train_datagen.flow_from_dataframe(
directory=dir_train,
dataframe=df_train,
x_col="id",
y_col="breed",
subset="validation",
batch_size=32,
seed=42,
shuffle=True,
class_mode="categorical",
target_size=(224,224)
)
# Out:
# Found 84 validated image filenames belonging to 10 classes.

# %%
test_datagen=ImageDataGenerator(rescale=1./255.)
#Generating batches of tensor image data with real-time data augmentation for Test set.

test_generator=test_datagen.flow_from_dataframe(
directory=dir_test,
dataframe=df_test,
x_col="id",
y_col=None,
batch_size=32,
seed=42,
shuffle=False,
class_mode=None,
target_size=(224,224),
)
# Out:
# Found 10357 validated image filenames.

# %%
classes=len(inc_breed)
classes
# Out:
# 10

# %%
#Freezing Resnet50 model to avoid weight updation
pretrained_model =ResNet50(
        weights='imagenet',
        include_top=False ,
        input_shape=(224,224,3)
    )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 12s 0us/step

# %%
#defing model
model =Sequential([ 
        pretrained_model,  
        Flatten(),
#         tf.keras.layers.GlobalAveragePooling2D(),
        Dense(2048, activation='relu'),
        Dropout(0.5),

        Dense(256, activation='relu'),
        Dropout(0.5),
        Dense(64, activation='relu'),
        Dropout(0.3),
    
        Dense(10, activation='softmax')
    ])

# %%
#as mentioned f1score, recall, precision are defined as our judging criteria for model
from keras import backend as bd

def recall_m(y_true, y_pred):
    true_positives =bd.sum(bd.round(bd.clip(y_true*y_pred,0,1)))
    possible_positives =bd.sum(bd.round(bd.clip(y_true,0,1)))
    recall =true_positives/(possible_positives+bd.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives =bd.sum(bd.round(bd.clip(y_true*y_pred,0,1)))
    predicted_positives =bd.sum(bd.round(bd.clip(y_pred,0,1)))
    precision = true_positives / (predicted_positives+bd.epsilon())
    return precision

def f1_m(y_true, y_pred): 
    precision =precision_m(y_true,y_pred)
    recall =recall_m(y_true,y_pred)
    return (2*((precision*recall)/(precision+recall+bd.epsilon())))

# %%
#stochastic gradient descent is used as optimizer and categorical_crossentropy is used for multiclass classification.
opt=Adam(learning_rate=1e-4)
model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['acc',f1_m,precision_m, recall_m])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 2048)              205522944
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 256)               524544
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 229,652,298
# Trainable params: 229,599,178
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
#model fitting with 50 epochs
step_size_ =train_generator.n//train_generator.batch_size
valid_step_size_ =validation_generator.n//validation_generator.batch_size
history =model.fit(train_generator,
                    steps_per_epoch=step_size_,
                    validation_data=validation_generator,
                    validation_steps=valid_step_size_ ,
                    epochs=50,
#                     
                   )
# Out:
# Epoch 1/50
# 23/23 [==============================] - 1288s 54s/step - loss: 6.1788 - acc: 0.1310 - f1_m: 0.1220 - precision_m: 0.1360 - recall_m: 0.1108 - val_loss: 2.6334 - val_acc: 0.1406 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 2/50
# 23/23 [==============================] - 1185s 52s/step - loss: 3.8967 - acc: 0.1793 - f1_m: 0.1559 - precision_m: 0.2030 - recall_m: 0.1278 - val_loss: 20.8226 - val_acc: 0.0938 - val_f1_m: 0.0937 - val_precision_m: 0.0938 - val_recall_m: 0.0938
# Epoch 3/50
# 23/23 [==============================] - 1133s 49s/step - loss: 2.6312 - acc: 0.2414 - f1_m: 0.1670 - precision_m: 0.3998 - recall_m: 0.1115 - val_loss: 29.5002 - val_acc: 0.0469 - val_f1_m: 0.0469 - val_precision_m: 0.0469 - val_recall_m: 0.0469
# Epoch 4/50
# 23/23 [==============================] - 1149s 50s/step - loss: 2.2510 - acc: 0.3200 - f1_m: 0.2528 - precision_m: 0.5797 - recall_m: 0.1667 - val_loss: 29.4804 - val_acc: 0.1719 - val_f1_m: 0.1719 - val_precision_m: 0.1719 - val_recall_m: 0.1719
# Epoch 5/50
# 23/23 [==============================] - 1124s 49s/step - loss: 1.9283 - acc: 0.4097 - f1_m: 0.3563 - precision_m: 0.6274 - recall_m: 0.2543 - val_loss: 12.1453 - val_acc: 0.0938 - val_f1_m: 0.0937 - val_precision_m: 0.0938 - val_recall_m: 0.0938
# Epoch 6/50
# 23/23 [==============================] - 1147s 50s/step - loss: 1.7131 - acc: 0.4676 - f1_m: 0.4350 - precision_m: 0.7137 - recall_m: 0.3161 - val_loss: 10.8808 - val_acc: 0.2031 - val_f1_m: 0.2031 - val_precision_m: 0.2031 - val_recall_m: 0.2031
# Epoch 7/50
# 23/23 [==============================] - 1171s 51s/step - loss: 1.4907 - acc: 0.5462 - f1_m: 0.5188 - precision_m: 0.7189 - recall_m: 0.4106 - val_loss: 5.8066 - val_acc: 0.2188 - val_f1_m: 0.2063 - val_precision_m: 0.2097 - val_recall_m: 0.2031
# Epoch 42/50
# 23/23 [==============================] - 513s 22s/step - loss: 0.2140 - acc: 0.9531 - f1_m: 0.9533 - precision_m: 0.9688 - recall_m: 0.9389 - val_loss: 1.3791 - val_acc: 0.6250 - val_f1_m: 0.6728 - val_precision_m: 0.8340 - val_recall_m: 0.5781
# Epoch 43/50
# 23/23 [==============================] - 561s 24s/step - loss: 0.2247 - acc: 0.9297 - f1_m: 0.9341 - precision_m: 0.9523 - recall_m: 0.9171 - val_loss: 1.1330 - val_acc: 0.7031 - val_f1_m: 0.7371 - val_precision_m: 0.8413 - val_recall_m: 0.6562
# Epoch 44/50
# 23/23 [==============================] - 527s 23s/step - loss: 0.2042 - acc: 0.9517 - f1_m: 0.9505 - precision_m: 0.9593 - recall_m: 0.9422 - val_loss: 1.7421 - val_acc: 0.6406 - val_f1_m: 0.6667 - val_precision_m: 0.7143 - val_recall_m: 0.6250
# Epoch 45/50
# 23/23 [==============================] - 560s 24s/step - loss: 0.1483 - acc: 0.9600 - f1_m: 0.9618 - precision_m: 0.9681 - recall_m: 0.9557 - val_loss: 1.0785 - val_acc: 0.7344 - val_f1_m: 0.7571 - val_precision_m: 0.8201 - val_recall_m: 0.7031
# Epoch 46/50
# 23/23 [==============================] - 534s 23s/step - loss: 0.1386 - acc: 0.9641 - f1_m: 0.9641 - precision_m: 0.9751 - recall_m: 0.9537 - val_loss: 1.1394 - val_acc: 0.7500 - val_f1_m: 0.7758 - val_precision_m: 0.8659 - val_recall_m: 0.7031
# Epoch 47/50
# 23/23 [==============================] - 534s 23s/step - loss: 0.2093 - acc: 0.9628 - f1_m: 0.9578 - precision_m: 0.9672 - recall_m: 0.9490 - val_loss: 1.3618 - val_acc: 0.7500 - val_f1_m: 0.7768 - val_precision_m: 0.8245 - val_recall_m: 0.7344
# Epoch 48/50
# 23/23 [==============================] - 564s 24s/step - loss: 0.1572 - acc: 0.9545 - f1_m: 0.9565 - precision_m: 0.9672 - recall_m: 0.9463 - val_loss: 1.0413 - val_acc: 0.7969 - val_f1_m: 0.8001 - val_precision_m: 0.8199 - val_recall_m: 0.7812
# Epoch 49/50
# 23/23 [==============================] - 569s 25s/step - loss: 0.2017 - acc: 0.9511 - f1_m: 0.9538 - precision_m: 0.9652 - recall_m: 0.9429 - val_loss: 1.9720 - val_acc: 0.7031 - val_f1_m: 0.6853 - val_precision_m: 0.7400 - val_recall_m: 0.6406
# Epoch 50/50
# 23/23 [==============================] - 553s 24s/step - loss: 0.2062 - acc: 0.9503 - f1_m: 0.9531 - precision_m: 0.9660 - recall_m: 0.9409 - val_loss: 0.9631 - val_acc: 0.8125 - val_f1_m: 0.8042 - val_precision_m: 0.8304 - val_recall_m: 0.7812

# %%
#plot of epoch vs accuracy for trainig set and epoch vs validation_accuracy for validation set
acc=history.history['acc']
val_acc=history.history['val_acc']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc))

fig=plt.figure(figsize=(14,7))
plt.plot(epochs,acc,'r', label='training Accuracy')
plt.plot(epochs,val_acc,'b', label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.title(' training vs validation accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
#plot of epoch vs loss for trainig set and epoch vs validation_loss for validation set

fig2=plt.figure(figsize=(14,7))
plt.plot(epochs,loss,'r', label='training Accuracy')
plt.plot(epochs,val_loss,'b', label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.title(' training vs validation accuracy')
plt.legend(loc='upper right')
plt.show()

# %%
#judging criterias of our model
loss, accuracy, f1_score, precision, recall = model.evaluate(validation_generator,batch_size=32)

print("Loss:", loss)
print("Accuracy:", accuracy)
print("F1 Score:", f1_score)
# Out:
# 3/3 [==============================] - 8s 2s/step - loss: 0.9963 - acc: 0.7857 - f1_m: 0.7606 - precision_m: 0.7984 - recall_m: 0.7271
# Loss: 0.9963433146476746
# Accuracy: 0.7857142686843872
# F1 Score: 0.760585606098175

# %%
#saving model for further use 
model.save("DogClassificationByResNet2.h5")

# %%
#prediction on test set using test generator
pred=model.predict(test_generator)
# Out:
# 324/324 [==============================] - 874s 3s/step

# %%
#sample test file
df_submission = pd.read_csv('D:/大四/Project/dog-breed-identification(1)/sample_submission.csv', usecols= inc_breed+['id'])
df_submission.head()
# Out:
#                                  id    beagle  chihuahua  doberman  \
# 0  000621fb3cbb32d8935728e48679680e  0.008333   0.008333  0.008333
# 1  00102ee9d8eb90812350685311fe5890  0.008333   0.008333  0.008333
# 2  0012a730dfa437f5f3613fb75efcd4ce  0.008333   0.008333  0.008333
# 3  001510bc8570bbeee98c8d80c8a95ec1  0.008333   0.008333  0.008333
# 4  001a5f3114548acdefa3d4da05474c2e  0.008333   0.008333  0.008333
#
#    french_bulldog  golden_retriever  malamute       pug  saint_bernard  \
# 0        0.008333          0.008333  0.008333  0.008333       0.008333
# 1        0.008333          0.008333  0.008333  0.008333       0.008333
# 2        0.008333          0.008333  0.008333  0.008333       0.008333
# 3        0.008333          0.008333  0.008333  0.008333       0.008333
# 4        0.008333          0.008333  0.008333  0.008333       0.008333
#
#    scottish_deerhound  tibetan_mastiff
# 0            0.008333         0.008333
# 1            0.008333         0.008333
# 2            0.008333         0.008333
# 3            0.008333         0.008333
# 4            0.008333         0.008333

# %%
#prediction on sample test file    
df_submission.iloc[:,1:] = pred
df_submission.head()
# Out:
#                                  id        beagle     chihuahua      doberman  \
# 0  000621fb3cbb32d8935728e48679680e  1.564680e-03  1.478515e-02  3.257943e-04
# 1  00102ee9d8eb90812350685311fe5890  3.126253e-11  2.028674e-10  9.946128e-12
# 2  0012a730dfa437f5f3613fb75efcd4ce  1.921955e-08  3.743296e-09  4.927445e-10
# 3  001510bc8570bbeee98c8d80c8a95ec1  2.634849e-04  5.788918e-03  9.890381e-04
# 4  001a5f3114548acdefa3d4da05474c2e  3.110748e-04  1.563248e-03  3.463719e-05
#
#    french_bulldog  golden_retriever      malamute           pug  \
# 0    6.691617e-04      9.779770e-01  2.906299e-03  4.697581e-04
# 1    2.460016e-10      9.738495e-11  9.613400e-01  2.911969e-09
# 2    9.277071e-09      5.983952e-08  4.546526e-09  5.229238e-09
# 3    5.460560e-03      6.116327e-04  3.375414e-04  9.685686e-01
# 4    1.386693e-04      1.838712e-04  6.444081e-03  3.278163e-04
#
#    saint_bernard  scottish_deerhound  tibetan_mastiff
# 0   4.705919e-04        2.980877e-04     5.334239e-04
# 1   1.345281e-09        9.076857e-08     3.865988e-02
# 2   4.053517e-09        9.999999e-01     3.668017e-09
# 3   2.492826e-03        1.442348e-02     1.063970e-03
# 4   6.007964e-04        9.567285e-01     3.366726e-02

# %%
#size of data
df_submission.shape
# Out:
# (10357, 11)
